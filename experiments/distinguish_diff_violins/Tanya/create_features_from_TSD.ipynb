# %% [markdown]
# # Ideas for feature engineering:
# https://towardsdatascience.com/feature-engineering-on-time-series-data-transforming-signal-data-of-a-smartphone-accelerometer-for-72cbe34b8a60
# 1) create features not from the whole dataset, but from the window sliding over the tsd

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../../src")
from FeaturesExtractorFromTSD import create_feature_dict_from_tsd

# %%
path = "../../results/TSD_angles/S001C/angl_head_inclination.csv"
tsd = pd.read_csv(path)['angle'].to_list()

# %%
plt.plot(tsd)

# %%
create_feature_dict_from_tsd(tsd)
# Out:
# {'mean': 71.67341226393911,
#  'var': 13.91629193915026,
#  'mad': 2.59656218213744,
#  'max': 80.05875992680592,
#  'min': 61.13559216498537,
#  'sma': 71.67341226393911,
#  'energy': 5150.994317495727,
#  'iqr': 5.1907127291476485,
#  'entropy': 5.722229006993177,
#  'correlation': 1.0,
#  'kurtosis': -0.5653517233836429,
#  'skewness': -0.004521012411118545,
#  'maxFreqCompInd': 0,
#  'maxFreqComp': (21932.064152765368-0j),
#  'meanFreq': (61.13559216498537-7.430512269386669e-16j),
#  'skewnessFreq': (17.448001995988797+1.8724941130731774e-19j),
#  'kurtosisFreq': (301.95362891581425+4.396007380271077e-18j),
#  'median': 71.63991128984853,
#  'peak_count': 36}
